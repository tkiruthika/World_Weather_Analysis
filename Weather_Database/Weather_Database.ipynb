# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 768

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | sogdiondon
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | mildura
# Processing Record 5 of Set 1 | zhezkazgan
# Processing Record 6 of Set 1 | haverfordwest
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | havre-saint-pierre
# Processing Record 10 of Set 1 | palmer
# Processing Record 11 of Set 1 | shibarghan
# City not found. Skipping...
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | komsomolskiy
# Processing Record 15 of Set 1 | chinsali
# Processing Record 16 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 1 | kuusamo
# Processing Record 18 of Set 1 | nipawin
# Processing Record 19 of Set 1 | chegdomyn
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | hami
# Processing Record 22 of Set 1 | daru
# Processing Record 23 of Set 1 | porto-vecchio
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | asau
# Processing Record 26 of Set 1 | aras
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | taga
# Processing Record 29 of Set 1 | la libertad
# Processing Record 30 of Set 1 | coihaique
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | viedma
# Processing Record 36 of Set 1 | ughelli
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | sioux lookout
# Processing Record 39 of Set 1 | jishou
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | srednekolymsk
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 1 | luwuk
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 1 | nyurba
# Processing Record 1 of Set 2 | villa maria
# Processing Record 2 of Set 2 | slave lake
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | poum
# Processing Record 5 of Set 2 | oistins
# Processing Record 6 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 2 | baker city
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | wanning
# Processing Record 10 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | manado
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | sinop
# Processing Record 16 of Set 2 | dingle
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | stawell
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | bharatpur
# Processing Record 24 of Set 2 | bozoum
# Processing Record 25 of Set 2 | dogondoutchi
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | lac du bonnet
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | leverano
# Processing Record 35 of Set 2 | itoman
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | mlonggo
# Processing Record 39 of Set 2 | alekseyevsk
# Processing Record 40 of Set 2 | wakema
# Processing Record 41 of Set 2 | lashio
# Processing Record 42 of Set 2 | independence
# Processing Record 43 of Set 2 | san quintin
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | seoul
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | yumen
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | rafraf
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | solnechnyy
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | ushuaia
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | plettenberg bay
# Processing Record 8 of Set 3 | kotido
# Processing Record 9 of Set 3 | nuuk
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | burnie
# Processing Record 12 of Set 3 | christchurch
# Processing Record 13 of Set 3 | harper
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | marsa matruh
# Processing Record 19 of Set 3 | kudahuvadhoo
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | steinbach
# Processing Record 22 of Set 3 | awjilah
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | tchollire
# Processing Record 25 of Set 3 | lipari
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | santiago
# Processing Record 29 of Set 3 | enshi
# Processing Record 30 of Set 3 | dergachi
# Processing Record 31 of Set 3 | virginia beach
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | martapura
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | saint-gabriel
# Processing Record 39 of Set 3 | carutapera
# Processing Record 40 of Set 3 | sao filipe
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | pinotepa nacional
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | pulandian
# Processing Record 48 of Set 3 | mackay
# Processing Record 49 of Set 3 | kloulklubed
# Processing Record 50 of Set 3 | myitkyina
# Processing Record 1 of Set 4 | jati
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | corinth
# Processing Record 4 of Set 4 | diamantino
# Processing Record 5 of Set 4 | sinnamary
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | arlit
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | cayenne
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | buchanan
# Processing Record 14 of Set 4 | tura
# Processing Record 15 of Set 4 | bentiu
# Processing Record 16 of Set 4 | vostok
# Processing Record 17 of Set 4 | boa vista
# Processing Record 18 of Set 4 | carballo
# Processing Record 19 of Set 4 | korem
# Processing Record 20 of Set 4 | oranjemund
# Processing Record 21 of Set 4 | lasa
# Processing Record 22 of Set 4 | uray
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | uyuni
# Processing Record 25 of Set 4 | hammerfest
# Processing Record 26 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 4 | wladyslawowo
# Processing Record 28 of Set 4 | yerbogachen
# Processing Record 29 of Set 4 | salinas
# Processing Record 30 of Set 4 | novosheshminsk
# Processing Record 31 of Set 4 | awbari
# Processing Record 32 of Set 4 | llandrindod wells
# Processing Record 33 of Set 4 | samana
# Processing Record 34 of Set 4 | manokwari
# Processing Record 35 of Set 4 | hohhot
# Processing Record 36 of Set 4 | pineville
# Processing Record 37 of Set 4 | talaya
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | phetchabun
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | yeppoon
# Processing Record 45 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | nikolskoye
# Processing Record 48 of Set 4 | ulaanbaatar
# Processing Record 49 of Set 4 | faanui
# Processing Record 50 of Set 4 | provideniya
# Processing Record 1 of Set 5 | leiva
# Processing Record 2 of Set 5 | kolo
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | segezha
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | linjiang
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | yellowknife
# Processing Record 10 of Set 5 | hilo
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | osmena
# Processing Record 13 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 5 | sabaudia
# Processing Record 15 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 5 | warrington
# Processing Record 17 of Set 5 | vama buzaului
# City not found. Skipping...
# Processing Record 18 of Set 5 | vao
# Processing Record 19 of Set 5 | ryotsu
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | touros
# Processing Record 23 of Set 5 | kalevala
# Processing Record 24 of Set 5 | batagay
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | bilaspur
# Processing Record 27 of Set 5 | ribeira brava
# Processing Record 28 of Set 5 | parit buntar
# Processing Record 29 of Set 5 | baglung
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | ornskoldsvik
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | veraval
# Processing Record 35 of Set 5 | henties bay
# Processing Record 36 of Set 5 | alnashi
# Processing Record 37 of Set 5 | hawick
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | kamaishi
# Processing Record 40 of Set 5 | ishigaki
# Processing Record 41 of Set 5 | kainantu
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | oktyabrskiy
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | pietarsaari
# Processing Record 46 of Set 5 | nara
# Processing Record 47 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | umm kaddadah
# Processing Record 50 of Set 5 | smidovich
# Processing Record 1 of Set 6 | surt
# Processing Record 2 of Set 6 | san luis
# Processing Record 3 of Set 6 | kerzhenets
# City not found. Skipping...
# Processing Record 4 of Set 6 | nizwa
# Processing Record 5 of Set 6 | kieta
# Processing Record 6 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 7 of Set 6 | izumo
# Processing Record 8 of Set 6 | raga
# Processing Record 9 of Set 6 | kununurra
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | severnyy
# Processing Record 12 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 6 | thunder bay
# Processing Record 14 of Set 6 | arica
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | talas
# Processing Record 18 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 20 of Set 6 | wajid
# Processing Record 21 of Set 6 | ndago
# Processing Record 22 of Set 6 | roebourne
# Processing Record 23 of Set 6 | sheopur
# Processing Record 24 of Set 6 | narsaq
# Processing Record 25 of Set 6 | xingtai
# Processing Record 26 of Set 6 | elwood
# Processing Record 27 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | anadyr
# Processing Record 32 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 6 | mount gambier
# Processing Record 34 of Set 6 | jibuti
# Processing Record 35 of Set 6 | samarai
# Processing Record 36 of Set 6 | olivenza
# Processing Record 37 of Set 6 | kathu
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | ujhani
# Processing Record 40 of Set 6 | leh
# Processing Record 41 of Set 6 | boda
# Processing Record 42 of Set 6 | padang
# Processing Record 43 of Set 6 | tilichiki
# Processing Record 44 of Set 6 | shingu
# Processing Record 45 of Set 6 | sechura
# Processing Record 46 of Set 6 | great falls
# Processing Record 47 of Set 6 | giulianova
# Processing Record 48 of Set 6 | arcata
# Processing Record 49 of Set 6 | menongue
# Processing Record 50 of Set 6 | kimbe
# Processing Record 1 of Set 7 | miri
# Processing Record 2 of Set 7 | kahului
# Processing Record 3 of Set 7 | keflavik
# Processing Record 4 of Set 7 | lebu
# Processing Record 5 of Set 7 | ostrovnoy
# Processing Record 6 of Set 7 | kasongo-lunda
# Processing Record 7 of Set 7 | aklavik
# Processing Record 8 of Set 7 | changping
# Processing Record 9 of Set 7 | kamen-rybolov
# Processing Record 10 of Set 7 | peque
# Processing Record 11 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 7 | newport
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | bengkulu
# Processing Record 15 of Set 7 | lamu
# Processing Record 16 of Set 7 | gambela
# Processing Record 17 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 7 | lavrentiya
# Processing Record 19 of Set 7 | riberalta
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | kangaatsiaq
# Processing Record 22 of Set 7 | valparaiso
# Processing Record 23 of Set 7 | atambua
# Processing Record 24 of Set 7 | aitape
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | alofi
# Processing Record 27 of Set 7 | altamira
# Processing Record 28 of Set 7 | san patricio
# Processing Record 29 of Set 7 | tumpat
# Processing Record 30 of Set 7 | bonthe
# Processing Record 31 of Set 7 | puerto del rosario
# Processing Record 32 of Set 7 | aksarka
# Processing Record 33 of Set 7 | saint-joseph
# Processing Record 34 of Set 7 | barcelos
# Processing Record 35 of Set 7 | lompoc
# Processing Record 36 of Set 7 | ziarat
# Processing Record 37 of Set 7 | umea
# Processing Record 38 of Set 7 | camana
# Processing Record 39 of Set 7 | grand gaube
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | carolina
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | vuktyl
# Processing Record 44 of Set 7 | kurilsk
# Processing Record 45 of Set 7 | assare
# Processing Record 46 of Set 7 | waipawa
# Processing Record 47 of Set 7 | ugoofaaru
# Processing Record 48 of Set 7 | khorinsk
# Processing Record 49 of Set 7 | inhambane
# Processing Record 50 of Set 7 | elat
# Processing Record 1 of Set 8 | sept-iles
# Processing Record 2 of Set 8 | poronaysk
# Processing Record 3 of Set 8 | goure
# Processing Record 4 of Set 8 | ust-kuyga
# Processing Record 5 of Set 8 | bandarbeyla
# Processing Record 6 of Set 8 | caravelas
# Processing Record 7 of Set 8 | gbadolite
# Processing Record 8 of Set 8 | arman
# Processing Record 9 of Set 8 | jaumave
# Processing Record 10 of Set 8 | izhevskoye
# Processing Record 11 of Set 8 | jhargram
# Processing Record 12 of Set 8 | sola
# Processing Record 13 of Set 8 | placido de castro
# Processing Record 14 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 8 | doka
# Processing Record 17 of Set 8 | san vicente
# Processing Record 18 of Set 8 | lumsden
# Processing Record 19 of Set 8 | traverse city
# Processing Record 20 of Set 8 | hualmay
# Processing Record 21 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 8 | aksu
# Processing Record 23 of Set 8 | nassau
# Processing Record 24 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 8 | praia da vitoria
# Processing Record 26 of Set 8 | tiksi
# Processing Record 27 of Set 8 | inirida
# Processing Record 28 of Set 8 | aykhal
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | lundazi
# Processing Record 31 of Set 8 | adrar
# Processing Record 32 of Set 8 | kabul
# Processing Record 33 of Set 8 | burns lake
# Processing Record 34 of Set 8 | hlinsko
# Processing Record 35 of Set 8 | san felipe
# Processing Record 36 of Set 8 | razole
# Processing Record 37 of Set 8 | sangar
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | jurado
# Processing Record 40 of Set 8 | florianopolis
# Processing Record 41 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 42 of Set 8 | ahipara
# Processing Record 43 of Set 8 | granville
# Processing Record 44 of Set 8 | cairns
# Processing Record 45 of Set 8 | verkhnetulomskiy
# Processing Record 46 of Set 8 | raudeberg
# Processing Record 47 of Set 8 | nhulunbuy
# Processing Record 48 of Set 8 | weligama
# Processing Record 49 of Set 8 | serowe
# Processing Record 50 of Set 8 | saldanha
# Processing Record 1 of Set 9 | airai
# Processing Record 2 of Set 9 | kruisfontein
# Processing Record 3 of Set 9 | gangtok
# Processing Record 4 of Set 9 | pemangkat
# Processing Record 5 of Set 9 | antofagasta
# Processing Record 6 of Set 9 | ust-maya
# Processing Record 7 of Set 9 | agadez
# Processing Record 8 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 9 | treinta y tres
# Processing Record 10 of Set 9 | curup
# Processing Record 11 of Set 9 | bambanglipuro
# Processing Record 12 of Set 9 | clearlake
# Processing Record 13 of Set 9 | urulga
# City not found. Skipping...
# Processing Record 14 of Set 9 | coahuayana
# Processing Record 15 of Set 9 | kachug
# Processing Record 16 of Set 9 | katangli
# Processing Record 17 of Set 9 | quatre cocos
# Processing Record 18 of Set 9 | krasnoselkup
# Processing Record 19 of Set 9 | ulaangom
# Processing Record 20 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 9 | karabulak
# Processing Record 22 of Set 9 | tabuk
# Processing Record 23 of Set 9 | ternate
# Processing Record 24 of Set 9 | nautla
# Processing Record 25 of Set 9 | melnik
# Processing Record 26 of Set 9 | khandyga
# Processing Record 27 of Set 9 | cockburn town
# Processing Record 28 of Set 9 | nome
# Processing Record 29 of Set 9 | hofn
# Processing Record 30 of Set 9 | opuwo
# Processing Record 31 of Set 9 | khunti
# Processing Record 32 of Set 9 | palu
# Processing Record 33 of Set 9 | buala
# Processing Record 34 of Set 9 | kaeo
# Processing Record 35 of Set 9 | swan hill
# Processing Record 36 of Set 9 | fortuna
# Processing Record 37 of Set 9 | mamallapuram
# Processing Record 38 of Set 9 | itapira
# Processing Record 39 of Set 9 | guerrero negro
# Processing Record 40 of Set 9 | olinda
# Processing Record 41 of Set 9 | kasongo
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | vredendal
# Processing Record 44 of Set 9 | yarada
# Processing Record 45 of Set 9 | nueve de julio
# Processing Record 46 of Set 9 | ville-marie
# Processing Record 47 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 9 | igualada
# Processing Record 49 of Set 9 | sangre grande
# Processing Record 50 of Set 9 | kapit
# Processing Record 1 of Set 10 | sergeyevka
# Processing Record 2 of Set 10 | port lincoln
# Processing Record 3 of Set 10 | minden
# Processing Record 4 of Set 10 | mahibadhoo
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | parainen
# Processing Record 7 of Set 10 | pak phanang
# Processing Record 8 of Set 10 | kismayo
# Processing Record 9 of Set 10 | darhan
# Processing Record 10 of Set 10 | port augusta
# Processing Record 11 of Set 10 | vanavara
# Processing Record 12 of Set 10 | ettenheim
# Processing Record 13 of Set 10 | netivot
# Processing Record 14 of Set 10 | kiruna
# Processing Record 15 of Set 10 | roald
# Processing Record 16 of Set 10 | katha
# City not found. Skipping...
# Processing Record 17 of Set 10 | hvide sande
# Processing Record 18 of Set 10 | san jose
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | presidencia roque saenz pena
# Processing Record 21 of Set 10 | severodvinsk
# Processing Record 22 of Set 10 | camocim
# Processing Record 23 of Set 10 | rio cuarto
# Processing Record 24 of Set 10 | antalaha
# Processing Record 25 of Set 10 | ravensburg
# Processing Record 26 of Set 10 | kirakira
# Processing Record 27 of Set 10 | licheng
# Processing Record 28 of Set 10 | port macquarie
# Processing Record 29 of Set 10 | namatanai
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | kingsville
# Processing Record 32 of Set 10 | springdale
# Processing Record 33 of Set 10 | barcelona
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | talnakh
# Processing Record 36 of Set 10 | mayumba
# Processing Record 37 of Set 10 | honiara
# Processing Record 38 of Set 10 | abapo
# Processing Record 39 of Set 10 | savanur
# Processing Record 40 of Set 10 | yeniseysk
# Processing Record 41 of Set 10 | yadrin
# Processing Record 42 of Set 10 | scarborough
# Processing Record 43 of Set 10 | abha
# Processing Record 44 of Set 10 | maniitsoq
# Processing Record 45 of Set 10 | calama
# Processing Record 46 of Set 10 | kamenka
# Processing Record 47 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 10 | luque
# Processing Record 49 of Set 10 | honolulu
# Processing Record 50 of Set 10 | dawei
# Processing Record 1 of Set 11 | ancud
# Processing Record 2 of Set 11 | sisimiut
# Processing Record 3 of Set 11 | korla
# Processing Record 4 of Set 11 | kresek
# Processing Record 5 of Set 11 | motygino
# Processing Record 6 of Set 11 | mazatlan
# Processing Record 7 of Set 11 | centralia
# Processing Record 8 of Set 11 | margate
# Processing Record 9 of Set 11 | sibolga
# Processing Record 10 of Set 11 | kousseri
# Processing Record 11 of Set 11 | half moon bay
# Processing Record 12 of Set 11 | ambilobe
# Processing Record 13 of Set 11 | siocon
# Processing Record 14 of Set 11 | auki
# Processing Record 15 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 11 | flinders
# Processing Record 17 of Set 11 | clonakilty
# Processing Record 18 of Set 11 | lagoa
# Processing Record 19 of Set 11 | gizo
# Processing Record 20 of Set 11 | parrita
# Processing Record 21 of Set 11 | amazar
# Processing Record 22 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 11 | puerto ayacucho
# Processing Record 24 of Set 11 | puerto baquerizo moreno
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | turukhansk
# Processing Record 27 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 11 | svetlaya
# Processing Record 30 of Set 11 | katima mulilo
# Processing Record 31 of Set 11 | labuhan
# Processing Record 32 of Set 11 | severnoye
# Processing Record 33 of Set 11 | prieska
# Processing Record 34 of Set 11 | barstow
# Processing Record 35 of Set 11 | kabanjahe
# Processing Record 36 of Set 11 | tekeli
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | monrovia
# Processing Record 39 of Set 11 | kharp
# Processing Record 40 of Set 11 | port-gentil
# Processing Record 41 of Set 11 | kem
# Processing Record 42 of Set 11 | edd
# Processing Record 43 of Set 11 | mnogovershinnyy
# Processing Record 44 of Set 11 | suao
# City not found. Skipping...
# Processing Record 45 of Set 11 | pokhara
# Processing Record 46 of Set 11 | saurimo
# Processing Record 47 of Set 11 | barand
# Processing Record 48 of Set 11 | leshukonskoye
# Processing Record 49 of Set 11 | nchelenge
# Processing Record 50 of Set 11 | dakar
# Processing Record 1 of Set 12 | marawi
# Processing Record 2 of Set 12 | camacha
# Processing Record 3 of Set 12 | havelock
# Processing Record 4 of Set 12 | mahajanga
# Processing Record 5 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 12 | high rock
# Processing Record 7 of Set 12 | ekhabi
# Processing Record 8 of Set 12 | iskateley
# Processing Record 9 of Set 12 | akyab
# Processing Record 10 of Set 12 | nacala
# Processing Record 11 of Set 12 | bathsheba
# Processing Record 12 of Set 12 | bac lieu
# Processing Record 13 of Set 12 | avera
# Processing Record 14 of Set 12 | klaksvik
# Processing Record 15 of Set 12 | hudson bay
# Processing Record 16 of Set 12 | alto araguaia
# Processing Record 17 of Set 12 | havoysund
# Processing Record 18 of Set 12 | rocha
# Processing Record 19 of Set 12 | paracuru
# Processing Record 20 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 21 of Set 12 | north bend
# Processing Record 22 of Set 12 | mayo
# Processing Record 23 of Set 12 | lucapa
# Processing Record 24 of Set 12 | khasan
# Processing Record 25 of Set 12 | thanh hoa
# Processing Record 26 of Set 12 | egvekinot
# Processing Record 27 of Set 12 | samagaltay
# Processing Record 28 of Set 12 | kavaratti
# Processing Record 29 of Set 12 | kurdzhinovo
# Processing Record 30 of Set 12 | casino
# Processing Record 31 of Set 12 | baie-comeau
# Processing Record 32 of Set 12 | ranong
# Processing Record 33 of Set 12 | bonavista
# Processing Record 34 of Set 12 | pitimbu
# Processing Record 35 of Set 12 | bereda
# Processing Record 36 of Set 12 | togur
# Processing Record 37 of Set 12 | kushmurun
# Processing Record 38 of Set 12 | namibe
# Processing Record 39 of Set 12 | kargopol
# Processing Record 40 of Set 12 | vila
# Processing Record 41 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 42 of Set 12 | tocopilla
# Processing Record 43 of Set 12 | iquitos
# Processing Record 44 of Set 12 | chalmette
# Processing Record 45 of Set 12 | kapitanivka
# Processing Record 46 of Set 12 | tanout
# Processing Record 47 of Set 12 | genhe
# Processing Record 48 of Set 12 | nizhniy tsasuchey
# Processing Record 49 of Set 12 | dire dawa
# Processing Record 50 of Set 12 | iza
# Processing Record 1 of Set 13 | kasane
# Processing Record 2 of Set 13 | denpasar
# Processing Record 3 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 13 | paka
# Processing Record 5 of Set 13 | inongo
# Processing Record 6 of Set 13 | price
# Processing Record 7 of Set 13 | panama city
# Processing Record 8 of Set 13 | jackson
# Processing Record 9 of Set 13 | copiapo
# Processing Record 10 of Set 13 | te anau
# Processing Record 11 of Set 13 | krasnovishersk
# Processing Record 12 of Set 13 | kerouane
# Processing Record 13 of Set 13 | phan thiet
# Processing Record 14 of Set 13 | olafsvik
# Processing Record 15 of Set 13 | cabra
# Processing Record 16 of Set 13 | boueni
# Processing Record 17 of Set 13 | cabedelo
# Processing Record 18 of Set 13 | sesheke
# Processing Record 19 of Set 13 | taos
# Processing Record 20 of Set 13 | abashiri
# Processing Record 21 of Set 13 | pacific grove
# Processing Record 22 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 13 | ketchikan
# Processing Record 24 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 13 | obo
# Processing Record 26 of Set 13 | dukat
# Processing Record 27 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 13 | chilca
# Processing Record 29 of Set 13 | mala
# Processing Record 30 of Set 13 | tabriz
# Processing Record 31 of Set 13 | odweyne
# Processing Record 32 of Set 13 | yamada
# Processing Record 33 of Set 13 | manggar
# Processing Record 34 of Set 13 | heihe
# Processing Record 35 of Set 13 | oksfjord
# Processing Record 36 of Set 13 | muros
# Processing Record 37 of Set 13 | xining
# Processing Record 38 of Set 13 | anloga
# Processing Record 39 of Set 13 | kutum
# Processing Record 40 of Set 13 | sorong
# Processing Record 41 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 13 | muravlenko
# Processing Record 43 of Set 13 | kazachka
# Processing Record 44 of Set 13 | piranhas
# Processing Record 45 of Set 13 | baniachang
# Processing Record 46 of Set 13 | tigil
# Processing Record 47 of Set 13 | dumai
# Processing Record 48 of Set 13 | rolla
# Processing Record 49 of Set 13 | guadalajara
# Processing Record 50 of Set 13 | nigde
# Processing Record 1 of Set 14 | heidenheim
# Processing Record 2 of Set 14 | apricena
# Processing Record 3 of Set 14 | itarema
# Processing Record 4 of Set 14 | madang
# Processing Record 5 of Set 14 | donja dubica
# Processing Record 6 of Set 14 | oriximina
# Processing Record 7 of Set 14 | udachnyy
# Processing Record 8 of Set 14 | boyolangu
# Processing Record 9 of Set 14 | la palma
# Processing Record 10 of Set 14 | manassas
# Processing Record 11 of Set 14 | iquique
# Processing Record 12 of Set 14 | fallon
# Processing Record 13 of Set 14 | tambura
# Processing Record 14 of Set 14 | vaitape
# Processing Record 15 of Set 14 | aroysund
# Processing Record 16 of Set 14 | yuksekova
# Processing Record 17 of Set 14 | cervo
# Processing Record 18 of Set 14 | springville
# Processing Record 19 of Set 14 | abancay
# Processing Record 20 of Set 14 | cilegon
# Processing Record 21 of Set 14 | la ciotat
# Processing Record 22 of Set 14 | bukachacha
# Processing Record 23 of Set 14 | los llanos de aridane
# Processing Record 24 of Set 14 | shenjiamen
# Processing Record 25 of Set 14 | vitim
# Processing Record 26 of Set 14 | grand-lahou
# Processing Record 27 of Set 14 | jutai
# Processing Record 28 of Set 14 | suoyarvi
# Processing Record 29 of Set 14 | lebyazhye
# Processing Record 30 of Set 14 | lichinga
# Processing Record 31 of Set 14 | valley city
# Processing Record 32 of Set 14 | dauphin
# Processing Record 33 of Set 14 | goya
# Processing Record 34 of Set 14 | skelleftea
# Processing Record 35 of Set 14 | conceicao do araguaia
# Processing Record 36 of Set 14 | port moresby
# Processing Record 37 of Set 14 | del rio
# Processing Record 38 of Set 14 | beckley
# Processing Record 39 of Set 14 | yulara
# Processing Record 40 of Set 14 | igrim
# Processing Record 41 of Set 14 | esil
# Processing Record 42 of Set 14 | fairbanks
# Processing Record 43 of Set 14 | tadine
# Processing Record 44 of Set 14 | paytug
# City not found. Skipping...
# Processing Record 45 of Set 14 | port hardy
# Processing Record 46 of Set 14 | mao
# Processing Record 47 of Set 14 | port blair
# Processing Record 48 of Set 14 | alpena
# Processing Record 49 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 14 | baruun-urt
# Processing Record 1 of Set 15 | pampa
# Processing Record 2 of Set 15 | flin flon
# Processing Record 3 of Set 15 | aleksandrov gay
# Processing Record 4 of Set 15 | vapnyarka
# Processing Record 5 of Set 15 | whitehorse
# Processing Record 6 of Set 15 | rapid valley
# Processing Record 7 of Set 15 | sadao
# Processing Record 8 of Set 15 | nakatsu
# Processing Record 9 of Set 15 | lamin
# Processing Record 10 of Set 15 | calvinia
# Processing Record 11 of Set 15 | dhidhdhoo
# Processing Record 12 of Set 15 | assiniboia
# Processing Record 13 of Set 15 | pouembout
# Processing Record 14 of Set 15 | acari
# Processing Record 15 of Set 15 | brae
# Processing Record 16 of Set 15 | lubao
# Processing Record 17 of Set 15 | boende
# Processing Record 18 of Set 15 | lixourion
# Processing Record 19 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 15 | basco
# Processing Record 21 of Set 15 | derbent
# Processing Record 22 of Set 15 | say
# Processing Record 23 of Set 15 | teahupoo
# Processing Record 24 of Set 15 | iranshahr
# Processing Record 25 of Set 15 | sao gabriel da cachoeira
# Processing Record 26 of Set 15 | satuk
# Processing Record 27 of Set 15 | gouyave
# Processing Record 28 of Set 15 | mattawa
# Processing Record 29 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 15 | iberia
# Processing Record 31 of Set 15 | ahuimanu
# Processing Record 32 of Set 15 | nioro
# Processing Record 33 of Set 15 | freeport
# Processing Record 34 of Set 15 | colares
# Processing Record 35 of Set 15 | asuncion
# Processing Record 36 of Set 15 | jodiya
# Processing Record 37 of Set 15 | kirillov
# Processing Record 38 of Set 15 | koumac
# Processing Record 39 of Set 15 | pennadam
# Processing Record 40 of Set 15 | qui nhon
# Processing Record 41 of Set 15 | axim
# Processing Record 42 of Set 15 | gushikawa
# Processing Record 43 of Set 15 | mangrol
# Processing Record 44 of Set 15 | lazaro cardenas
# Processing Record 45 of Set 15 | maues
# Processing Record 46 of Set 15 | labytnangi
# Processing Record 47 of Set 15 | kedougou
# Processing Record 48 of Set 15 | karla
# Processing Record 49 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 50 of Set 15 | toshkivka
# Processing Record 1 of Set 16 | bud
# Processing Record 2 of Set 16 | farah
# Processing Record 3 of Set 16 | iqaluit
# Processing Record 4 of Set 16 | jinka
# Processing Record 5 of Set 16 | grand junction
# Processing Record 6 of Set 16 | fukue
# Processing Record 7 of Set 16 | teya
# Processing Record 8 of Set 16 | japura
# Processing Record 9 of Set 16 | emerald
# Processing Record 10 of Set 16 | dossor
# Processing Record 11 of Set 16 | batsfjord
# Processing Record 12 of Set 16 | byron bay
# Processing Record 13 of Set 16 | warri
# Processing Record 14 of Set 16 | richmond
# Processing Record 15 of Set 16 | kapan
# Processing Record 16 of Set 16 | medina del campo
# Processing Record 17 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 16 | hanna
# --------------------
# Data Retrieval Complete
# --------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp Current Description  \
# 0           cape town -33.9258   18.4232     82.11           clear sky
# 1            cherskiy  68.7500  161.3000    -29.65          few clouds
# 2             mildura -34.2000  142.1500     88.07       broken clouds
# 3          zhezkazgan  47.8043   67.7144     13.98          few clouds
# 4       haverfordwest  51.8017   -4.9691     47.34     overcast clouds
# 5              albany  42.6001  -73.9662      8.55           clear sky
# 6              castro -24.7911  -50.0119     61.70     overcast clouds
# 7  havre-saint-pierre  50.2334  -63.5986      3.20           clear sky
# 8              palmer  42.1584  -72.3287     14.61           clear sky
# 9      ribeira grande  38.5167  -28.7000     59.61          few clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0            0.0        57           0        6.91      ZA
# 1            0.0            0.0       100          18        2.44      RU
# 2            0.0            0.0        20          84       11.50      AU
# 3            0.0            0.0        73          20       17.90      KZ
# 4            0.0            0.0        89         100        8.01      GB
# 5            0.0            0.0        75           8        2.89      US
# 6            0.0            0.0        98          88        4.50      BR
# 7            0.0            0.0        59           0       10.36      CA
# 8            0.0            0.0        68           0        6.91      US
# 9            0.0            0.0        73          13        9.57      PT

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           cape town      ZA -33.9258   18.4232     82.11        57
# 1            cherskiy      RU  68.7500  161.3000    -29.65       100
# 2             mildura      AU -34.2000  142.1500     88.07        20
# 3          zhezkazgan      KZ  47.8043   67.7144     13.98        73
# 4       haverfordwest      GB  51.8017   -4.9691     47.34        89
# ..                ...     ...      ...       ...       ...       ...
# 701             warri      NG   5.5167    5.7500     77.29        81
# 702          richmond      US  37.5538  -77.4603     27.18        68
# 703             kapan      AM  39.2075   46.4058     35.80        34
# 704  medina del campo      ES  41.3124   -4.9141     26.64        84
# 705             hanna      CA  51.6334 -111.9018     29.86        76
#
#      Cloudiness  Wind Speed Current Description
# 0             0        6.91           clear sky
# 1            18        2.44          few clouds
# 2            84       11.50       broken clouds
# 3            20       17.90          few clouds
# 4           100        8.01     overcast clouds
# ..          ...         ...                 ...
# 701           0        0.98           clear sky
# 702           0        3.00           clear sky
# 703          38        1.03    scattered clouds
# 704           3        2.51           clear sky
# 705          75       13.00       broken clouds
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy_database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
